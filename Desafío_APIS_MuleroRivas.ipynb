# %% [markdown]
# En consideración que la after class el profesor mencionó que podía estar o no relacionado con el Dataset elegido se trabajó con dos ejemplos, uno no relacionado y otro con cierta relación.

# %%
#Import de library

import requests
import json
import pandas as pd
import time
import datetime

# %%
# Obtengo la URL

response = requests.request('GET', url='https://api2.binance.com/api/v3/ticker/24hr')
data_json = response.json()

# %%
# Verifico que es una Lista. 
# también se verifico en JSON Editor. Donde indicó que se trata de una lista de 2139 ítems y con 21 columnas cada uno. Se trata de tipos de criptomonedas y en las columnas datos y evolución de la misma; valores de cierre, apertura, precio más alto, más bajo, entre otros.
type(data_json)
# Out:
# list

# %%
pd.DataFrame(data_json)
# Out:
#          symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0        ETHBTC  -0.00120300             -1.615       0.07379598
# 1        LTCBTC  -0.00026000             -5.840       0.00429838
# 2        BNBBTC  -0.00055600             -3.674       0.01472707
# 3        NEOBTC  -0.00001200             -3.183       0.00037079
# 4       QTUMETH  -0.00000800             -0.514       0.00154938
# ...         ...          ...                ...              ...
# 2134  MAGICBUSD   0.14730000             24.267       0.72974128
# 2135  MAGICUSDT   0.14730000             24.247       0.72575333
# 2136    BUSDRON  -0.02000000             -0.431       4.63778620
# 2137    HIFIETH  -0.00001690             -4.816       0.00034089
# 2138   HIFIUSDT   0.02060000              4.144       0.51340980
#
#      prevClosePrice   lastPrice        lastQty    bidPrice         bidQty  \
# 0        0.07450200  0.07329900     1.99190000  0.07329300     4.00000000
# ...

# %%
import requests
import pandas as pd
import json

# %%
response = requests.get('https://randomuser.me/api/')
response.status_code
# Out:
# 200

# %% [markdown]
# Para el siguiente caso usamos esta API la cual tiene cierta relación con nuestro proyecto de DataScience (Abandono de Clientes Bancarios).
# Esta API nos brinda información acerca de un generador de datos de un usuario falso.

# %%
response.text
# Out:
# '{"results":[{"gender":"female","name":{"title":"Ms","first":"Rosie","last":"Simmons"},"location":{"street":{"number":1639,"name":"Patrick Street"},"city":"Trim","state":"Donegal","country":"Ireland","postcode":86086,"coordinates":{"latitude":"1.8242","longitude":"55.1879"},"timezone":{"offset":"+8:00","description":"Beijing, Perth, Singapore, Hong Kong"}},"email":"rosie.simmons@example.com","login":{"uuid":"ddfd2ae2-dd77-4196-821c-13d7da389a17","username":"smallbutterfly278","password":"arianna","salt":"3CChJAGk","md5":"8754676e75fa530b29ee476952c5670b","sha1":"a0e3bdcec0f4de1dd0ea910d479a6f38136b0bb4","sha256":"1a6032c8463d53160ad485320cf2ef794d7ff53332fb806d1bb968e93483f60d"},"dob":{"date":"1992-11-29T02:25:06.647Z","age":30},"registered":{"date":"2011-08-28T10:32:08.694Z","age":11},"phone":"051-255-6149","cell":"081-785-2564","id":{"name":"PPS","value":"4731340T"},"picture":{"large":"https://randomuser.me/api/portraits/women/79.jpg","medium":"https://randomuser.me/api/portraits/m
# ...

# %%
data = json.loads(response.text)
data
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Rosie', 'last': 'Simmons'},
#    'location': {'street': {'number': 1639, 'name': 'Patrick Street'},
#     'city': 'Trim',
#     'state': 'Donegal',
#     'country': 'Ireland',
#     'postcode': 86086,
#     'coordinates': {'latitude': '1.8242', 'longitude': '55.1879'},
#     'timezone': {'offset': '+8:00',
#      'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#    'email': 'rosie.simmons@example.com',
#    'login': {'uuid': 'ddfd2ae2-dd77-4196-821c-13d7da389a17',
#     'username': 'smallbutterfly278',
#     'password': 'arianna',
#     'salt': '3CChJAGk',
#     'md5': '8754676e75fa530b29ee476952c5670b',
#     'sha1': 'a0e3bdcec0f4de1dd0ea910d479a6f38136b0bb4',
#     'sha256': '1a6032c8463d53160ad485320cf2ef794d7ff53332fb806d1bb968e93483f60d'},
#    'dob': {'date': '1992-11-29T02:25:06.647Z', 'age': 30},
#    'registered': {'date': '2011-08-28T10:32:08.694Z', 'age': 11},
#    'phone': '051-255-6149',
# ...

# %%
data.keys()
# Out:
# dict_keys(['results', 'info'])

# %%
data['results']
# Out:
# [{'gender': 'female',
#   'name': {'title': 'Ms', 'first': 'Rosie', 'last': 'Simmons'},
#   'location': {'street': {'number': 1639, 'name': 'Patrick Street'},
#    'city': 'Trim',
#    'state': 'Donegal',
#    'country': 'Ireland',
#    'postcode': 86086,
#    'coordinates': {'latitude': '1.8242', 'longitude': '55.1879'},
#    'timezone': {'offset': '+8:00',
#     'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#   'email': 'rosie.simmons@example.com',
#   'login': {'uuid': 'ddfd2ae2-dd77-4196-821c-13d7da389a17',
#    'username': 'smallbutterfly278',
#    'password': 'arianna',
#    'salt': '3CChJAGk',
#    'md5': '8754676e75fa530b29ee476952c5670b',
#    'sha1': 'a0e3bdcec0f4de1dd0ea910d479a6f38136b0bb4',
#    'sha256': '1a6032c8463d53160ad485320cf2ef794d7ff53332fb806d1bb968e93483f60d'},
#   'dob': {'date': '1992-11-29T02:25:06.647Z', 'age': 30},
#   'registered': {'date': '2011-08-28T10:32:08.694Z', 'age': 11},
#   'phone': '051-255-6149',
#   'cell': '081-785-2564',
# ...

# %%
data['info']
# Out:
# {'seed': '756b9ab40b62a53f', 'results': 1, 'page': 1, 'version': '1.4'}

# %% [markdown]
# Generamos el DataFrame

# %%
pd.DataFrame.from_dict(data['results'])
# Out:
#    gender                                               name  \
# 0  female  {'title': 'Ms', 'first': 'Rosie', 'last': 'Sim...
#
#                                             location  \
# 0  {'street': {'number': 1639, 'name': 'Patrick S...
#
#                        email  \
# 0  rosie.simmons@example.com
#
#                                                login  \
# 0  {'uuid': 'ddfd2ae2-dd77-4196-821c-13d7da389a17...
#
#                                                dob  \
# 0  {'date': '1992-11-29T02:25:06.647Z', 'age': 30}
#
#                                         registered         phone  \
# 0  {'date': '2011-08-28T10:32:08.694Z', 'age': 11}  051-255-6149
#
#            cell                                    id  \
# 0  081-785-2564  {'name': 'PPS', 'value': '4731340T'}
#
#                                              picture nat
# 0  {'large': 'https://randomuser.me/api/portraits...  IE
